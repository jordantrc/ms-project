# %%
# Test the image input/output and processing
import numpy as np
import cv2
from matplotlib.pyplot import imshow
from PIL import Image

# %matplotlib inline
# preview the image
image = 'frames/00001.jpg'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-0afd19f0bfdc> in <module>()
#       1 # Test the image input/output and processing
#       2 import numpy as np
# ----> 3 import cv2
#       4 from matplotlib.pyplot import imshow
#       5 from PIL import Image
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# preview the image
img = Image.open(image)
imshow(np.asarray(img))

# %%
# test image flip
img_flipped = cv2.flip(img, flipCode=1)
imshow(np.asarray(img_flipped))
